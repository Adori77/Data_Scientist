# %% [markdown]
# # Descripcion Dataset: Advanced House Pricing

# %% [markdown]
# Dataset original: https://www.kaggle.com/c/house-prices-advanced-regression-techniques

# %% [markdown]
# MSSubClass: Identifies the type of dwelling involved in the sale.
#
#         20	1-STORY 1946 & NEWER ALL STYLES
#         30	1-STORY 1945 & OLDER
#         40	1-STORY W/FINISHED ATTIC ALL AGES
#         45	1-1/2 STORY - UNFINISHED ALL AGES
#         50	1-1/2 STORY FINISHED ALL AGES
#         60	2-STORY 1946 & NEWER
#         70	2-STORY 1945 & OLDER
#         75	2-1/2 STORY ALL AGES
#         80	SPLIT OR MULTI-LEVEL
#         85	SPLIT FOYER
#         90	DUPLEX - ALL STYLES AND AGES
#        120	1-STORY PUD (Planned Unit Development) - 1946 & NEWER
#        150	1-1/2 STORY PUD - ALL AGES
#        160	2-STORY PUD - 1946 & NEWER
#        180	PUD - MULTILEVEL - INCL SPLIT LEV/FOYER
#        190	2 FAMILY CONVERSION - ALL STYLES AND AGES
#
# MSZoning: Identifies the general zoning classification of the sale.
#
#        A	Agriculture
#        C	Commercial
#        FV	Floating Village Residential
#        I	Industrial
#        RH	Residential High Density
#        RL	Residential Low Density
#        RP	Residential Low Density Park
#        RM	Residential Medium Density
#
# LotFrontage: Linear feet of street connected to property
#
# LotArea: Lot size in square feet
#
# Street: Type of road access to property
#
#        Grvl	Gravel
#        Pave	Paved
#
# Alley: Type of alley access to property
#
#        Grvl	Gravel
#        Pave	Paved
#        NA 	No alley access
#
# LotShape: General shape of property
#
#        Reg	Regular
#        IR1	Slightly irregular
#        IR2	Moderately Irregular
#        IR3	Irregular
#
# LandContour: Flatness of the property
#
#        Lvl	Near Flat/Level
#        Bnk	Banked - Quick and significant rise from street grade to building
#        HLS	Hillside - Significant slope from side to side
#        Low	Depression
#
# Utilities: Type of utilities available
#
#        AllPub	All public Utilities (E,G,W,& S)
#        NoSewr	Electricity, Gas, and Water (Septic Tank)
#        NoSeWa	Electricity and Gas Only
#        ELO	Electricity only
#
# LotConfig: Lot configuration
#
#        Inside	Inside lot
#        Corner	Corner lot
#        CulDSac	Cul-de-sac
#        FR2	Frontage on 2 sides of property
#        FR3	Frontage on 3 sides of property
#
# LandSlope: Slope of property
#
#        Gtl	Gentle slope
#        Mod	Moderate Slope
#        Sev	Severe Slope
#
# Neighborhood: Physical locations within Ames city limits
#
#        Blmngtn	Bloomington Heights
#        Blueste	Bluestem
#        BrDale	Briardale
#        BrkSide	Brookside
#        ClearCr	Clear Creek
#        CollgCr	College Creek
#        Crawfor	Crawford
#        Edwards	Edwards
#        Gilbert	Gilbert
#        IDOTRR	Iowa DOT and Rail Road
#        MeadowV	Meadow Village
#        Mitchel	Mitchell
#        Names	North Ames
#        NoRidge	Northridge
#        NPkVill	Northpark Villa
#        NridgHt	Northridge Heights
#        NWAmes	Northwest Ames
#        OldTown	Old Town
#        SWISU	South & West of Iowa State University
#        Sawyer	Sawyer
#        SawyerW	Sawyer West
#        Somerst	Somerset
#        StoneBr	Stone Brook
#        Timber	Timberland
#        Veenker	Veenker
#
# Condition1: Proximity to various conditions
#
#        Artery	Adjacent to arterial street
#        Feedr	Adjacent to feeder street
#        Norm	Normal
#        RRNn	Within 200' of North-South Railroad
#        RRAn	Adjacent to North-South Railroad
#        PosN	Near positive off-site feature--park, greenbelt, etc.
#        PosA	Adjacent to postive off-site feature
#        RRNe	Within 200' of East-West Railroad
#        RRAe	Adjacent to East-West Railroad
#
# Condition2: Proximity to various conditions (if more than one is present)
#
#        Artery	Adjacent to arterial street
#        Feedr	Adjacent to feeder street
#        Norm	Normal
#        RRNn	Within 200' of North-South Railroad
#        RRAn	Adjacent to North-South Railroad
#        PosN	Near positive off-site feature--park, greenbelt, etc.
#        PosA	Adjacent to postive off-site feature
#        RRNe	Within 200' of East-West Railroad
#        RRAe	Adjacent to East-West Railroad
#
# BldgType: Type of dwelling
#
#        1Fam	Single-family Detached
#        2FmCon	Two-family Conversion; originally built as one-family dwelling
#        Duplx	Duplex
#        TwnhsE	Townhouse End Unit
#        TwnhsI	Townhouse Inside Unit
#
# HouseStyle: Style of dwelling
#
#        1Story	One story
#        1.5Fin	One and one-half story: 2nd level finished
#        1.5Unf	One and one-half story: 2nd level unfinished
#        2Story	Two story
#        2.5Fin	Two and one-half story: 2nd level finished
#        2.5Unf	Two and one-half story: 2nd level unfinished
#        SFoyer	Split Foyer
#        SLvl	Split Level
#
# OverallQual: Rates the overall material and finish of the house
#
#        10	Very Excellent
#        9	Excellent
#        8	Very Good
#        7	Good
#        6	Above Average
#        5	Average
#        4	Below Average
#        3	Fair
#        2	Poor
#        1	Very Poor
#
# OverallCond: Rates the overall condition of the house
#
#        10	Very Excellent
#        9	Excellent
#        8	Very Good
#        7	Good
#        6	Above Average
#        5	Average
#        4	Below Average
#        3	Fair
#        2	Poor
#        1	Very Poor
#
# YearBuilt: Original construction date
#
# YearRemodAdd: Remodel date (same as construction date if no remodeling or additions)
#
# RoofStyle: Type of roof
#
#        Flat	Flat
#        Gable	Gable
#        Gambrel	Gabrel (Barn)
#        Hip	Hip
#        Mansard	Mansard
#        Shed	Shed
#
# RoofMatl: Roof material
#
#        ClyTile	Clay or Tile
#        CompShg	Standard (Composite) Shingle
#        Membran	Membrane
#        Metal	Metal
#        Roll	Roll
#        Tar&Grv	Gravel & Tar
#        WdShake	Wood Shakes
#        WdShngl	Wood Shingles
#
# Exterior1st: Exterior covering on house
#
#        AsbShng	Asbestos Shingles
#        AsphShn	Asphalt Shingles
#        BrkComm	Brick Common
#        BrkFace	Brick Face
#        CBlock	Cinder Block
#        CemntBd	Cement Board
#        HdBoard	Hard Board
#        ImStucc	Imitation Stucco
#        MetalSd	Metal Siding
#        Other	Other
#        Plywood	Plywood
#        PreCast	PreCast
#        Stone	Stone
#        Stucco	Stucco
#        VinylSd	Vinyl Siding
#        Wd Sdng	Wood Siding
#        WdShing	Wood Shingles
#
# Exterior2nd: Exterior covering on house (if more than one material)
#
#        AsbShng	Asbestos Shingles
#        AsphShn	Asphalt Shingles
#        BrkComm	Brick Common
#        BrkFace	Brick Face
#        CBlock	Cinder Block
#        CemntBd	Cement Board
#        HdBoard	Hard Board
#        ImStucc	Imitation Stucco
#        MetalSd	Metal Siding
#        Other	Other
#        Plywood	Plywood
#        PreCast	PreCast
#        Stone	Stone
#        Stucco	Stucco
#        VinylSd	Vinyl Siding
#        Wd Sdng	Wood Siding
#        WdShing	Wood Shingles
#
# MasVnrType: Masonry veneer type
#
#        BrkCmn	Brick Common
#        BrkFace	Brick Face
#        CBlock	Cinder Block
#        None	None
#        Stone	Stone
#
# MasVnrArea: Masonry veneer area in square feet
#
# ExterQual: Evaluates the quality of the material on the exterior
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        Po	Poor
#
# ExterCond: Evaluates the present condition of the material on the exterior
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        Po	Poor
#
# Foundation: Type of foundation
#
#        BrkTil	Brick & Tile
#        CBlock	Cinder Block
#        PConc	Poured Contrete
#        Slab	Slab
#        Stone	Stone
#        Wood	Wood
#
# BsmtQual: Evaluates the height of the basement
#
#        Ex	Excellent (100+ inches)
#        Gd	Good (90-99 inches)
#        TA	Typical (80-89 inches)
#        Fa	Fair (70-79 inches)
#        Po	Poor (<70 inches
#        NA	No Basement
#
# BsmtCond: Evaluates the general condition of the basement
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical - slight dampness allowed
#        Fa	Fair - dampness or some cracking or settling
#        Po	Poor - Severe cracking, settling, or wetness
#        NA	No Basement
#
# BsmtExposure: Refers to walkout or garden level walls
#
#        Gd	Good Exposure
#        Av	Average Exposure (split levels or foyers typically score average or above)
#        Mn	Mimimum Exposure
#        No	No Exposure
#        NA	No Basement
#
# BsmtFinType1: Rating of basement finished area
#
#        GLQ	Good Living Quarters
#        ALQ	Average Living Quarters
#        BLQ	Below Average Living Quarters
#        Rec	Average Rec Room
#        LwQ	Low Quality
#        Unf	Unfinshed
#        NA	No Basement
#
# BsmtFinSF1: Type 1 finished square feet
#
# BsmtFinType2: Rating of basement finished area (if multiple types)
#
#        GLQ	Good Living Quarters
#        ALQ	Average Living Quarters
#        BLQ	Below Average Living Quarters
#        Rec	Average Rec Room
#        LwQ	Low Quality
#        Unf	Unfinshed
#        NA	No Basement
#
# BsmtFinSF2: Type 2 finished square feet
#
# BsmtUnfSF: Unfinished square feet of basement area
#
# TotalBsmtSF: Total square feet of basement area
#
# Heating: Type of heating
#
#        Floor	Floor Furnace
#        GasA	Gas forced warm air furnace
#        GasW	Gas hot water or steam heat
#        Grav	Gravity furnace
#        OthW	Hot water or steam heat other than gas
#        Wall	Wall furnace
#
# HeatingQC: Heating quality and condition
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        Po	Poor
#
# CentralAir: Central air conditioning
#
#        N	No
#        Y	Yes
#
# Electrical: Electrical system
#
#        SBrkr	Standard Circuit Breakers & Romex
#        FuseA	Fuse Box over 60 AMP and all Romex wiring (Average)
#        FuseF	60 AMP Fuse Box and mostly Romex wiring (Fair)
#        FuseP	60 AMP Fuse Box and mostly knob & tube wiring (poor)
#        Mix	Mixed
#
# 1stFlrSF: First Floor square feet
#
# 2ndFlrSF: Second floor square feet
#
# LowQualFinSF: Low quality finished square feet (all floors)
#
# GrLivArea: Above grade (ground) living area square feet
#
# BsmtFullBath: Basement full bathrooms
#
# BsmtHalfBath: Basement half bathrooms
#
# FullBath: Full bathrooms above grade
#
# HalfBath: Half baths above grade
#
# Bedroom: Bedrooms above grade (does NOT include basement bedrooms)
#
# Kitchen: Kitchens above grade
#
# KitchenQual: Kitchen quality
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical/Average
#        Fa	Fair
#        Po	Poor
#
# TotRmsAbvGrd: Total rooms above grade (does not include bathrooms)
#
# Functional: Home functionality (Assume typical unless deductions are warranted)
#
#        Typ	Typical Functionality
#        Min1	Minor Deductions 1
#        Min2	Minor Deductions 2
#        Mod	Moderate Deductions
#        Maj1	Major Deductions 1
#        Maj2	Major Deductions 2
#        Sev	Severely Damaged
#        Sal	Salvage only
#
# Fireplaces: Number of fireplaces
#
# FireplaceQu: Fireplace quality
#
#        Ex	Excellent - Exceptional Masonry Fireplace
#        Gd	Good - Masonry Fireplace in main level
#        TA	Average - Prefabricated Fireplace in main living area or Masonry Fireplace in basement
#        Fa	Fair - Prefabricated Fireplace in basement
#        Po	Poor - Ben Franklin Stove
#        NA	No Fireplace
#
# GarageType: Garage location
#
#        2Types	More than one type of garage
#        Attchd	Attached to home
#        Basment	Basement Garage
#        BuiltIn	Built-In (Garage part of house - typically has room above garage)
#        CarPort	Car Port
#        Detchd	Detached from home
#        NA	No Garage
#
# GarageYrBlt: Year garage was built
#
# GarageFinish: Interior finish of the garage
#
#        Fin	Finished
#        RFn	Rough Finished
#        Unf	Unfinished
#        NA	No Garage
#
# GarageCars: Size of garage in car capacity
#
# GarageArea: Size of garage in square feet
#
# GarageQual: Garage quality
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical/Average
#        Fa	Fair
#        Po	Poor
#        NA	No Garage
#
# GarageCond: Garage condition
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical/Average
#        Fa	Fair
#        Po	Poor
#        NA	No Garage
#
# PavedDrive: Paved driveway
#
#        Y	Paved
#        P	Partial Pavement
#        N	Dirt/Gravel
#
# WoodDeckSF: Wood deck area in square feet
#
# OpenPorchSF: Open porch area in square feet
#
# EnclosedPorch: Enclosed porch area in square feet
#
# 3SsnPorch: Three season porch area in square feet
#
# ScreenPorch: Screen porch area in square feet
#
# PoolArea: Pool area in square feet
#
# PoolQC: Pool quality
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        NA	No Pool
#
# Fence: Fence quality
#
#        GdPrv	Good Privacy
#        MnPrv	Minimum Privacy
#        GdWo	Good Wood
#        MnWw	Minimum Wood/Wire
#        NA	No Fence
#
# MiscFeature: Miscellaneous feature not covered in other categories
#
#        Elev	Elevator
#        Gar2	2nd Garage (if not described in garage section)
#        Othr	Other
#        Shed	Shed (over 100 SF)
#        TenC	Tennis Court
#        NA	None
#
# MiscVal: $Value of miscellaneous feature
#
# MoSold: Month Sold (MM)
#
# YrSold: Year Sold (YYYY)
#
# SaleType: Type of sale
#
#        WD 	Warranty Deed - Conventional
#        CWD	Warranty Deed - Cash
#        VWD	Warranty Deed - VA Loan
#        New	Home just constructed and sold
#        COD	Court Officer Deed/Estate
#        Con	Contract 15% Down payment regular terms
#        ConLw	Contract Low Down payment and low interest
#        ConLI	Contract Low Interest
#        ConLD	Contract Low Down
#        Oth	Other
#
# SaleCondition: Condition of sale
#
#        Normal	Normal Sale
#        Abnorml	Abnormal Sale -  trade, foreclosure, short sale
#        AdjLand	Adjoining Land Purchase
#        Alloca	Allocation - two linked properties with separate deeds, typically condo with a garage unit
#        Family	Sale between family members
#        Partial	Home was not completed when last assessed (associated with New Homes)

# %% [markdown]
#  We will make a work plan

# %% [markdown]
# * Analysis the target
# * Filling missing values
# * Feature Engineering
# * Converting categorical to numerical
# * Modeling and predicting

# %% [markdown]
# # Import libraries

# %%
# !pip install shap
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 572.6/572.6 kB 5.9 MB/s eta 0:00:00
# ...

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import rcParams
import seaborn as sns
import missingno as msno

from sklearn.impute import SimpleImputer
from sklearn.metrics import make_scorer
from sklearn.model_selection import KFold, cross_val_score
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split, cross_val_score

#XGBoost
import xgboost as xgb
from xgboost import plot_tree

#Shap value
import shap
from scipy.stats import pearsonr

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Semana9_MachineLearning/Datasets_ML/XGB_HousePricing_data.csv')
print('Size: ',df.shape)
# Out:
# Size:  (1460, 81)

# %%
df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# 0         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 1         Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 2         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 3         Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 4         Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0       0      2    2008        WD         Normal     208500
# ...

# %%
#TO DO: Drop ID column
df.drop('Id', axis=1,inplace=True)

# %% [markdown]
# # Target analysis

# %%
df['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
# TO DO: EDA univariable del target
#Análisis: Graficamos el Target para obtener el tipo de distribución

plt.figure(figsize=(12,7))

sns.histplot(df['SalePrice'])
plt.title('House price distribution histogram', fontsize=18)
plt.show()

# %% [markdown]
# La clase target es asimetrica positiva (skewed). En regresión es importante que el target se aproxime lo máximo posible a una distribucion normal. Por lo que se aplica la transformación logaritmica en estos casos.

# %%
# TO DO: Transformacion logarítimica del target -> Crea una nueva columna target 'SalePrice_log' y elimina el antiguo target
df['SalePrice_log'] = np.log1p(df['SalePrice'])

# %%
# TO DO: EDA univariable del nuevo target
plt.figure(figsize=(12,7))

sns.histplot(df['SalePrice_log'])
plt.title('House price distribution histogram after fix', fontsize=18)
plt.show()

#Ahora tiene una distribucion normal

# %% [markdown]
# ...Arreglado!

# %%
# Quito la variable TARGET = df['SalePrice'] para que no me la tome como feature
df.drop('SalePrice', axis=1, inplace=True)

# %% [markdown]
# # Preprocessing

# %%
df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# 0         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 1         Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 2         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 3         Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 4         Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice_log
# ...

# %%
def column_report(df_x):
    a = pd.DataFrame(df_x.dtypes, columns=['dtype'])
    b = pd.DataFrame(df_x.isna().sum(), columns=['nulls'])
    b['%nulls'] = round(100*b['nulls']/ df_x.shape[0],2)
    c = df_x.describe(include='all').transpose()
    return a.join(b).join(c).sort_values(by=['dtype','nulls'])

report = column_report(df)

# %%
pd.set_option('display.max_rows', 1000)
report
# Out:
#                  dtype  nulls  %nulls   count unique      top  freq  \
# MSSubClass       int64      0    0.00  1460.0    NaN      NaN   NaN
# LotArea          int64      0    0.00  1460.0    NaN      NaN   NaN
# OverallQual      int64      0    0.00  1460.0    NaN      NaN   NaN
# OverallCond      int64      0    0.00  1460.0    NaN      NaN   NaN
# YearBuilt        int64      0    0.00  1460.0    NaN      NaN   NaN
# YearRemodAdd     int64      0    0.00  1460.0    NaN      NaN   NaN
# BsmtFinSF1       int64      0    0.00  1460.0    NaN      NaN   NaN
# BsmtFinSF2       int64      0    0.00  1460.0    NaN      NaN   NaN
# BsmtUnfSF        int64      0    0.00  1460.0    NaN      NaN   NaN
# TotalBsmtSF      int64      0    0.00  1460.0    NaN      NaN   NaN
# 1stFlrSF         int64      0    0.00  1460.0    NaN      NaN   NaN
# 2ndFlrSF         int64      0    0.00  1460.0    NaN      NaN   NaN
# LowQualFinSF     int64      0    0.00  1460.0    NaN      NaN   NaN
# ...

# %% [markdown]
# ## Correlation

# %% [markdown]
# Vemos las variables más correlacionadas con el target antes de eliminar nulos. Esto nos ayudará a tomar decisiones en la gestion de nulos antes de borrar ninguna columna.

# %%
corr=df.corr()
# Out:
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.

# %%
highest_corr_features = corr.index[abs(corr['SalePrice_log']) > 0.5]  # Es para decidir que varias hay que eliminar dependiendo de su correlacion con el target
highest_corr_features
# Out:
# Index(['OverallQual', 'YearBuilt', 'YearRemodAdd', 'TotalBsmtSF', '1stFlrSF',
#        'GrLivArea', 'FullBath', 'TotRmsAbvGrd', 'GarageYrBlt', 'GarageCars',
#        'GarageArea', 'SalePrice_log'],
#       dtype='object')

# %%
corr_list = pd.DataFrame(corr['SalePrice_log'].abs().sort_values(ascending=False))
corr_list.rename(columns={'SalePrice_log':'correlation'},inplace=True)
corr_list[corr_list['correlation']>0.50]
# Out:
#                correlation
# SalePrice_log     1.000000
# OverallQual       0.817185
# GrLivArea         0.700927
# GarageCars        0.680625
# GarageArea        0.650888
# TotalBsmtSF       0.612134
# 1stFlrSF          0.596981
# FullBath          0.594771
# YearBuilt         0.586570
# YearRemodAdd      0.565608
# GarageYrBlt       0.541073
# TotRmsAbvGrd      0.534422

# %% [markdown]
# ## Missing data

# %%
# Analisis de nulos
report[report['nulls']>0].sort_values(by='nulls',ascending=False)
# Out:
#                 dtype  nulls  %nulls   count unique     top  freq  \
# PoolQC         object   1453   99.52       7      3      Gd     3
# MiscFeature    object   1406   96.30      54      4    Shed    49
# Alley          object   1369   93.77      91      2    Grvl    50
# Fence          object   1179   80.75     281      4   MnPrv   157
# FireplaceQu    object    690   47.26     770      5      Gd   380
# LotFrontage   float64    259   17.74  1201.0    NaN     NaN   NaN
# GarageFinish   object     81    5.55    1379      3     Unf   605
# GarageCond     object     81    5.55    1379      5      TA  1326
# GarageQual     object     81    5.55    1379      5      TA  1311
# GarageYrBlt   float64     81    5.55  1379.0    NaN     NaN   NaN
# GarageType     object     81    5.55    1379      6  Attchd   870
# BsmtFinType2   object     38    2.60    1422      6     Unf  1256
# BsmtExposure   object     38    2.60    1422      4      No   953
# ...

# %% [markdown]
# Elimina columnas con alto % nulos

# %% [markdown]
# Se tomó esta decisión ya que las variables que tienen mayor porcentaje de nulos no muestran una alta correlacion con nuestro TARGET
#
# Cuando el nulo puede ser cualquier valor encontrar una manera de llenarlo puede resultar muy difícil

# %%
# TO DO: Elimina las columnas con un alto % de nulos. Eelige un límite = % de nulos inaceptable a tu criterio para eliminar nulos.
cols_drop = list(report[report['%nulls']>10].index)
cols_drop
# Out:
# ['LotFrontage', 'FireplaceQu', 'Fence', 'Alley', 'MiscFeature', 'PoolQC']

# %%
df.drop(cols_drop,axis=1,inplace=True)

# %%
report = column_report(df[df.isnull().sum()[df.isnull().sum()>0].index])
report
# Out:
#                 dtype  nulls  %nulls   count unique     top  freq  \
# MasVnrArea    float64      8    0.55  1452.0    NaN     NaN   NaN
# GarageYrBlt   float64     81    5.55  1379.0    NaN     NaN   NaN
# Electrical     object      1    0.07    1459      5   SBrkr  1334
# MasVnrType     object      8    0.55    1452      4    None   864
# BsmtQual       object     37    2.53    1423      4      TA   649
# BsmtCond       object     37    2.53    1423      4      TA  1311
# BsmtFinType1   object     37    2.53    1423      6     Unf   430
# BsmtExposure   object     38    2.60    1422      4      No   953
# BsmtFinType2   object     38    2.60    1422      6     Unf  1256
# GarageType     object     81    5.55    1379      6  Attchd   870
# GarageFinish   object     81    5.55    1379      3     Unf   605
# GarageQual     object     81    5.55    1379      5      TA  1311
# GarageCond     object     81    5.55    1379      5      TA  1326
#
# ...

# %% [markdown]
# Sustituye nulos por moda en categoricos

# %%
categorical_nulls = list(report[report['dtype']=='object'].index)
categorical_nulls
# Out:
# ['Electrical',
#  'MasVnrType',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtFinType1',
#  'BsmtExposure',
#  'BsmtFinType2',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond']

# %%
def imputer_frequent(df,col):
    imputer = SimpleImputer(missing_values=np.NaN, strategy='most_frequent')  # most_frequent es imputar la moda
    df[col] = imputer.fit_transform(df[col].values.reshape(-1,1))[:,0]

# %%
#TO DO: aplicar el imputer_frequent() en todas las variables categoricas con nulos
for i in categorical_nulls:
  imputer_frequent(df,i)

# %% [markdown]
# Sustituye nulos por media o promedio en numericos

# %%
report = column_report(df[df.isnull().sum()[df.isnull().sum()>0].index])
report
# Out:
#                dtype  nulls  %nulls   count         mean         std     min  \
# MasVnrArea   float64      8    0.55  1452.0   103.685262  181.066207     0.0
# GarageYrBlt  float64     81    5.55  1379.0  1978.506164   24.689725  1900.0
#
#                 25%     50%     75%     max
# MasVnrArea      0.0     0.0   166.0  1600.0
# GarageYrBlt  1961.0  1980.0  2002.0  2010.0

# %%
def imputer_mean(df,col):
    imputer = SimpleImputer(missing_values=np.NaN, strategy='mean')
    df[col] = imputer.fit_transform(df[col].values.reshape(-1,1))[:,0]

# %%
numeric_nulls = list(report[report['dtype']=='float64'].index)
numeric_nulls
# Out:
# ['MasVnrArea', 'GarageYrBlt']

# %%
#TO DO: aplicar el imputer_mean() en todas las variables numericas con nulos
for i in numeric_nulls:
  imputer_mean(df,i)

# %%
#CHECK: Los nulos deben ser 0
print('Nulos: ',df.isnull().sum().sum())
# Out:
# Nulos:  0

# %% [markdown]
# ## Encoding

# %%
target='SalePrice_log'
features = list(df.columns)
features.remove(target)

# %%
def obtener_lista_variables(dataset):
    lista_numericas=[]
    lista_boolean=[]
    lista_categoricas=[]
    lista_categoricas_2_bool=[]

    for i in dataset:
        if    (dataset[i].dtype=="float64" or dataset[i].dtype=="int64") and len(dataset[i].unique())!= 2  and i not in target:
              lista_numericas.append(i)
        if  (dataset[i].dtype=="float64" or dataset[i].dtype=="int64") and len(dataset[i].unique())== 2  and i not in target:
              lista_boolean.append(i)
        if  (dataset[i].dtype=="object")  and len(dataset[i].unique())!= 2 and i not in target:
              lista_categoricas.append(i)
        if  (dataset[i].dtype=="object") and len(dataset[i].unique())== 2 and i not in target:
              lista_categoricas_2_bool.append(i)

    return lista_numericas, lista_boolean, lista_categoricas, lista_categoricas_2_bool

# %%
lista_numericas, lista_boolean, lista_categoricas, lista_categoricas_2_bool = obtener_lista_variables(df)

# %%
print("Target a predecir: ",target)
print(df.shape[1]-1, "variables en total")

print(len(lista_numericas), "variables numéricas: ",lista_numericas)
print(len(lista_boolean), "variables booleanas: ",lista_boolean)

print(len(lista_categoricas), "variables categóricas: ",lista_categoricas)
print(len(lista_categoricas_2_bool), "variables categóricas convertibles a booleano: ",lista_categoricas_2_bool)
# Out:
# Target a predecir:  SalePrice_log
# 73 variables en total
# 35 variables numéricas:  ['MSSubClass', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold']
# 0 variables booleanas:  []
# ...

# %% [markdown]
# ### One-hot-encoding

# %%
# TO DO: Aplica un one-hot-encoder sobre las variables categoricas (lista_categoricas)
df = pd.get_dummies(data=df,
                              prefix=None,
                              prefix_sep="_",
                              columns=lista_categoricas,
                              dtype="int8")

# %% [markdown]
# ### Categoricos a booleanos

# %%
# TO DO: Convierte a booleano las variables categoricas de 2 clases (lista_categoricas_2_bool)
df = pd.get_dummies(data=df,
                                prefix=None,
                                prefix_sep="_",
                                drop_first=True,
                                columns=lista_categoricas_2_bool,
                                dtype="int8")

# %%
df.head()
# Out:
#    MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0          60     8450            7            5       2003          2003
# 1          20     9600            6            8       1976          1976
# 2          60    11250            7            5       2001          2002
# 3          70     9550            7            5       1915          1970
# 4          60    14260            8            5       2000          2000
#
#    MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  ...  SaleType_WD  \
# 0       196.0         706           0        150  ...            1
# 1         0.0         978           0        284  ...            1
# 2       162.0         486           0        434  ...            1
# 3         0.0         216           0        540  ...            1
# 4       350.0         655           0        490  ...            1
#
#    SaleCondition_Abnorml  SaleCondition_AdjLand  SaleCondition_Alloca  \
# ...

# %% [markdown]
# ## Variables altamente correlacionadas

# %%
def correlation(dataset, threshold):
    col_corr = list() # Set of all the names of deleted columns
    colnames = list()
    rownames = list()
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if (corr_matrix.iloc[i, j] >= threshold) and (corr_matrix.columns[j] not in col_corr):
                colnames.append(corr_matrix.columns[i]) # getting the name of column
                rownames.append(corr_matrix.index[j])
                col_corr.append(corr_matrix.iloc[i, j])
    Y = pd.DataFrame([colnames,rownames,col_corr]).transpose()
    Y.rename(columns = { 0: 'F1', 1: 'F2', 2: 'CORR' }, inplace=True)
    return Y

# %%
# Estas parejs están correlacionadas entre ellas arriba del 95% estas se crearon en el one hot encoding
highly_corr = correlation(df, 0.95)
highly_corr
# Out:
#                       F1                   F2      CORR
# 0     Exterior2nd_CBlock   Exterior1st_CBlock       1.0
# 1    Exterior2nd_CmentBd  Exterior1st_CemntBd  0.974171
# 2    Exterior2nd_MetalSd  Exterior1st_MetalSd  0.973065
# 3    Exterior2nd_VinylSd  Exterior1st_VinylSd  0.977525
# 4  SaleCondition_Partial         SaleType_New  0.986819

# %%
def print_corr(feat1, feat2):
  print('Correlacion ', feat1, '-', feat2, ': ', df[[feat1,feat2]].corr().abs().iloc[0,1])

# %%
print_corr('Exterior1st_CemntBd', 'SalePrice_log')
print_corr('Exterior2nd_CmentBd', 'SalePrice_log')
# Out:
# Correñacion  Exterior1st_CemntBd - SalePrice_log :  0.09458267185815897
# Correñacion  Exterior2nd_CmentBd - SalePrice_log :  0.09222886222077507

# %%
print_corr('Exterior1st_MetalSd', 'SalePrice_log')
print_corr('Exterior2nd_MetalSd', 'SalePrice_log')
# Out:
# Correñacion  Exterior1st_MetalSd - SalePrice_log :  0.1732922528461496
# Correñacion  Exterior2nd_MetalSd - SalePrice_log :  0.1678870409788757

# %%
print_corr('Exterior1st_VinylSd', 'SalePrice_log')
print_corr('Exterior2nd_VinylSd', 'SalePrice_log')
# Out:
# Correñacion  Exterior1st_VinylSd - SalePrice_log :  0.33613830989931626
# Correñacion  Exterior2nd_VinylSd - SalePrice_log :  0.33744369635947763

# %%
print_corr('SaleType_New', 'SalePrice_log')
print_corr('SaleCondition_Partial', 'SalePrice_log')
# Out:
# Correñacion  SaleType_New - SalePrice_log :  0.32918988225795665
# Correñacion  SaleCondition_Partial - SalePrice_log :  0.32447133475562573

# %% [markdown]
# Eliminamos la variable de cada pareja con menos correlación con el target

# %%
# TO DO: Elige qué variable eliminar de cada pareja altamente correlacionada y eliminala del dataset
df.drop('Exterior2nd_CBlock', axis=1, inplace=True)
df.drop('Exterior2nd_CmentBd', axis=1, inplace=True)
df.drop('Exterior2nd_MetalSd', axis=1, inplace=True)
df.drop('Exterior1st_VinylSd', axis=1, inplace=True)
df.drop('SaleCondition_Partial', axis=1, inplace=True)

# %%
# CHECK: Aqui deberia devolver una tabla vacía
correlation(df, 0.95)
# Out:
# Empty DataFrame
# Columns: [F1, F2, CORR]
# Index: []

# %% [markdown]
# ## Split train and test

# %%
target='SalePrice_log'
features = list(df.columns)
features.remove(target)

# %%
# TO DO: Divide dataset en matriz de FEATURES (X) y TARGET (y)
y = df[target]
X = df[features]

# %%
# Divide X-y en Train (70%) y Test (30%)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ## Estandarizacion

# %% [markdown]
# En algoritmos de Árbol de Decisión como el XGBoost no es necesario estandarizar!

# %% [markdown]
# # Modeling and predicting

# %%
model_XGBReg = xgb.XGBRegressor(colsample_bytree=0.5, n_estimators=1000, objective='reg:squarederror')

# %%
eval_set = [(X_train, y_train), (X_test, y_test)]
model_XGBReg.fit(
    X_train,
    y_train,
    eval_metric = "rmse",
    eval_set = eval_set,
    verbose = False
)
# Out:
# `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.5, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=1000, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
# Prediction and metrics

# TO DO: Calcula RMSE en train y test
y_pred_train = model_XGBReg.predict(X_train)
rmse_train = np.sqrt(np.mean((y_pred_train - y_train)**2))

y_pred_test = model_XGBReg.predict(X_test)
rmse_test = np.sqrt(np.mean((y_pred_test - y_test)**2))

print("Training RMSE: %.5f" %rmse_train)
print("Test RMSE: %.5f" %rmse_test)
# Out:
# Training RMSE: 0.00111
# Test RMSE: 0.14074

# %%
#Error distribution
error = y_pred_test - y_test.values
plt.figure(figsize=(12, 7))
plt.title('Distribucion del error (SalePrice_log)', fontsize=15)
sns.histplot(error)
plt.show()

# %%
# Absolute Error distribution
error = np.abs(y_pred_test - y_test.values)
plt.figure(figsize=(12, 7))
plt.title('Distribucion del error (SalePrice_log)', fontsize=15)
sns.histplot(error)
plt.show()

# %% [markdown]
# Transformacion exponencial para revertir la trasnformacion logaritimica aplicada sobre el output:

# %%
# TO DO: Revierte la transformacion logaritmica en el predict y en el test con una transformacion exponencial
y_predict_exp = np.floor(np.expm1(model_XGBReg.predict(X_test)))
y_test_exp = np.floor(np.expm1(y_test))
error_exp = y_predict_exp - y_test_exp

# %%
plt.figure(figsize=(12, 7))
plt.title('Distribucion del error real (SalePrice)', fontsize=15)
sns.histplot(error_exp)
plt.show()

# %%
print('RMSE test (real):',np.sqrt(np.mean((y_predict_exp - y_test_exp) ** 2)))
print('R^2 score (real):',r2_score(y_test_exp,y_predict_exp))
# Out:
# RMSE test (real): 27597.81917249306
# R^2 score (real): 0.8908528210873768

# %% [markdown]
# ## Interpretabilidad del modelo

# %%
#Visualiza un árbol concreto de los [n_estimators] que utiliza el XGBoost
plt.figure(figsize=(30, 20))
plot_tree(model_XGBReg, num_trees=5)
plt.show()

# %% [markdown]
# https://mljar.com/blog/feature-importance-xgboost/

# %%
# Feature importance: numero de veces que emplea la variable para determinar el output
rcParams['figure.figsize'] = 12,8
sns.set(context="talk")
xgb.plot_importance(model_XGBReg, max_num_features=20, importance_type='weight')
plt.show()

# %%
#SHAP value: peso en el output final
explainer = shap.TreeExplainer(model_XGBReg)
shap_values = explainer.shap_values(X_test)
plt.title('SHAP values')
shap.summary_plot(shap_values, X_test, plot_type="bar", max_display=20)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
shap.summary_plot(shap_values, X_test)
# Out:
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored

# %%
# TO DO: En base a las anteriores graficas, ¿cual dirias que son las top3 variables que determinan el precio de una casa?

# %% [markdown]
# GrLivArea, OverallQual y LotArea

# %% [markdown]
# ## EXTRA: Hyperparameter Gridsearch

# %% [markdown]
# ¿Cómo saber qué parámetros son los mejores para este problema?

# %% [markdown]
# https://www.kaggle.com/tilii7/hyperparameter-grid-search-with-xgboost

# %% [markdown]
# ...si aplicasemos hyper tuning de parámetros daríamos con la siguiente configuración:

# %%
model_XGBReg_hyper = xgb.XGBRegressor(objective='reg:squarederror',colsample_bytree=0.4603, gamma=0.0468,
                             learning_rate=0.05, max_depth=3,
                             min_child_weight=1.7817, n_estimators=2200,
                             reg_alpha=0.4640, reg_lambda=0.8571,
                             subsample=0.5213, random_state =7, nthread = -1)

# %%
eval_set = [(X_train, y_train), (X_test, y_test)]
model_XGBReg_hyper.fit(
    X_train,
    y_train,
    eval_metric = "rmse",
    eval_set = eval_set,
    verbose = False
)
#Prediction and metrics
y_pred_train = model_XGBReg_hyper.predict(X_train)
rmse_train = np.sqrt(np.mean((y_pred_train - y_train) ** 2))

y_pred_test = model_XGBReg_hyper.predict(X_test)
rmse_test = np.sqrt(np.mean((y_pred_test - y_test) ** 2))

print("Training RMSE: %.5f" %rmse_train)
print("Test RMSE: %.5f" %rmse_test)
# Out:
# `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
# Training RMSE: 0.08011
# Test RMSE: 0.12589

# %%
#Error distribution
error_hyper = y_pred_test - y_test.values
plt.figure(figsize=(12, 7))
plt.title('Distribucion del error (SalePrice_log)', fontsize=15)
sns.histplot(error_hyper)
plt.show()

# %%
y_predict_exp = np.floor(np.expm1(model_XGBReg_hyper.predict(X_test)))
y_test_exp = np.floor(np.expm1(y_test))
error_exp = y_predict_exp - y_test_exp

# %%
print('RMSE test (real):',np.sqrt(np.mean((y_predict_exp - y_test_exp) ** 2)))
print('R^2 score (real):',r2_score(y_test_exp,y_predict_exp))
# Out:
# RMSE test (real): 26673.063365954065
# R^2 score (real): 0.8980449412809854

# %% [markdown]
# ## Predict

# %%
y_predict = model_XGBReg.predict(X_test)
y_predict[:10]
# Out:
# array([11.894243, 12.778047, 11.608576, 11.811919, 12.759526, 11.258615,
#        12.411066, 11.908916, 11.35569 , 11.844155], dtype=float32)

# %%
#Transformacion exponencial para revertir la transformacion logaritimica aplicada sobre el output
y_predict_exp = np.floor(np.expm1(model_XGBReg.predict(X_test)))
y_predict_exp[:10]
# Out:
# array([146420., 354351., 110036., 134849., 347848.,  77544., 245502.,
#        148584.,  85449., 139266.], dtype=float32)

# %%
y_predict_exp = np.floor(np.expm1(model_XGBReg.predict(X_test)))
y_test_exp = np.floor(np.expm1(y_test))
error_exp = y_predict_exp - y_test_exp
plt.figure(figsize=(12, 7))
plt.title('Distribucion del error (SalePrice)', fontsize=15)
sns.histplot(error_exp)
plt.show()

# %%
#TO DO: Visualiza el resultado de tu regresión en una comparativa del dato real vs la rpedeccion (scatter plot)
plt.figure(figsize=(12, 7))
plt.scatter(y_test_exp, y_predict_exp)
plt.plot(y_test_exp,y_test_exp,'magenta')
plt.legend(['Regresión Ideal','Tu Regresión'])
plt.xlabel('True values')
plt.ylabel('Predicted values')
plt.title('House Price: True vs Predicted (Test data)')
plt.show()
